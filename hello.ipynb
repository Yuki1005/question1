# %%
#発展課題
number1 = float(input("整数を入力してください\n"))
number2 = float(input("割る数（整数）を入力してください\n"))
print("商は" , int(number1 // number2) , "、余りは" , int(number1 % number2) , "です" , sep = '')
# Out:
# 商は15、余りは7です

# %%
#発展課題
print("整数を入力してください")
number1 = float(input())
print("割る数（整数）を入力してください")
number2 = float(input())
print("商は" , int(number1 // number2) , "、余りは" , int(number1 % number2) , "です" , sep = '')
# Out:
# 整数を入力してください
# 割る数（整数）を入力してください
# 商は15、余りは7です
