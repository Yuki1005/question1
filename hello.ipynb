# %%
#発展課題
number1 = float(input("整数を入力してください\n"))
number2 = float(input("割る数（整数）を入力してください\n"))
print("商は" , int(number1 // number2) , "、余りは" , int(number1 % number2) , "です" , sep = '')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-a4f12e28966e> in <module>
#       1 #発展課題
# ----> 2 number1 = float(input("整数を入力してください\n"))
#       3 number2 = float(input("割る数（整数）を入力してください\n"))
#       4 print("商は" , int(number1 // number2) , "、余りは" , int(number1 % number2) , "です" , sep = '')
#
# ValueError: could not convert string to float: ''
